# %% [markdown]
# Leetcode problem number 231 : https://leetcode.com/problems/power-of-two/submissions/2025875696/

# %%
class Solution:
    def isPowerOfTwo(self, n: int) -> bool:
        return n > 0 and (n & (n-1)) == 0
        #if n > 0:
            #return (n & (n-1)) == 0
